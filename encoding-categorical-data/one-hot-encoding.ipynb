# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('car_price_prediction_.csv')

# %%
df = df.iloc[:, 1:]

# %%
df.head()
# Out:
#    Brand  Year  Engine Size Fuel Type Transmission  Mileage Condition  \
# 0  Tesla  2016          2.3    Petrol       Manual   114832       New
# 1    BMW  2018          4.4  Electric       Manual   143190      Used
# 2   Audi  2013          4.5  Electric       Manual   181601       New
# 3  Tesla  2011          4.1    Diesel    Automatic    68682       New
# 4   Ford  2009          2.6    Diesel       Manual   223009  Like New
#
#       Price     Model
# 0  26613.92   Model X
# 1  14679.61  5 Series
# 2  44402.61        A4
# 3  86374.33   Model Y
# 4  73577.10   Mustang

# %%
df['Condition'].nunique()
# Out:
# 3

# %%
pd.get_dummies(df,columns=['Condition', 'Fuel Type'])
# Out:
#        Brand  Year  Engine Size Transmission  Mileage     Price     Model  \
# 0      Tesla  2016          2.3       Manual   114832  26613.92   Model X
# 1        BMW  2018          4.4       Manual   143190  14679.61  5 Series
# 2       Audi  2013          4.5       Manual   181601  44402.61        A4
# 3      Tesla  2011          4.1    Automatic    68682  86374.33   Model Y
# 4       Ford  2009          2.6       Manual   223009  73577.10   Mustang
# ...      ...   ...          ...          ...      ...       ...       ...
# 2495    Audi  2020          2.4    Automatic    22650  61384.10        Q5
# 2496    Audi  2001          5.7       Manual    77701  24710.35        A3
# 2497    Ford  2021          1.1       Manual   272827  29902.45    Fiesta
# 2498    Audi  2002          4.5       Manual   229164  46085.67        Q5
# 2499  Toyota  2005          4.6    Automatic    80978  16594.14      RAV4
#
#       Condition_Like New  Condition_New  Condition_Used  Fuel Type_Diesel  \
# ...

# %%
 pd.get_dummies(df,columns=['Condition', 'Fuel Type'], drop_first=True)
# Out:
#        Brand  Year  Engine Size Transmission  Mileage     Price     Model  \
# 0      Tesla  2016          2.3       Manual   114832  26613.92   Model X
# 1        BMW  2018          4.4       Manual   143190  14679.61  5 Series
# 2       Audi  2013          4.5       Manual   181601  44402.61        A4
# 3      Tesla  2011          4.1    Automatic    68682  86374.33   Model Y
# 4       Ford  2009          2.6       Manual   223009  73577.10   Mustang
# ...      ...   ...          ...          ...      ...       ...       ...
# 2495    Audi  2020          2.4    Automatic    22650  61384.10        Q5
# 2496    Audi  2001          5.7       Manual    77701  24710.35        A3
# 2497    Ford  2021          1.1       Manual   272827  29902.45    Fiesta
# 2498    Audi  2002          4.5       Manual   229164  46085.67        Q5
# 2499  Toyota  2005          4.6    Automatic    80978  16594.14      RAV4
#
#       Condition_New  Condition_Used  Fuel Type_Electric  Fuel Type_Hybrid  \
# ...

# %%
x = df.drop('Price',axis=1)
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder()

# %%
x_train_new = ohe.fit_transform(x_train[['Condition', 'Fuel Type']]).toarray()
x_test_new = ohe.fit_transform(x_train[['Condition', 'Fuel Type']]).toarray()

# %%
x_train[['Brand', 'Mil']]
